# %%
# poster ID
# owner ID
# item ID
# item name
# description
# date posted

# 802 items

import random

f = open("Desktop/nouns.txt")
arr = []
for line in f:
    line = line[:-1]
    arr.append(line)
f.close()

items = {}

for i in xrange(208):
    
    date = "2017"
    day = str(random.randint(1,30))
    
    if len(day) == 1:
        day = "0" + day
        
    month = str(random.randint(6,12))
    
    if len(month) == 1:
        month = "0" + month
        
    date = date + "-" + month + "-" + day
    
    owner = random.randint(1,1000)
    
    items[i + 1] = {}
    items[i + 1]['name'] = arr[i]
    items[i + 1]['owner'] = owner
    items[i + 1]['claimant'] = owner
    items[i + 1]['desc'] = arr[i] + arr[i + 1]
    items[i + 1]['date'] = date
    
    print str(i)
    print items[i + 1]

output = []
for item in items:
    line = ""
    line += items[item]['name'] + "\t"
    line += str(items[item]['owner']) + "\t"
    line += str(items[item]['claimant']) + "\t"
    line += items[item]['desc'] + "\t"
    line += items[item]['date']
    
    print line
    
    output.append(line)

f = open("Desktop/items.txt", "w")
for item in output:
    f.write(item + "\n")
f.close()
# Out:
# 0
# {'owner': 591, 'date': '2017-06-27', 'desc': 'accountachiever', 'name': 'account', 'claimant': 591}
# 1
# {'owner': 21, 'date': '2017-09-04', 'desc': 'achieveracoustics', 'name': 'achiever', 'claimant': 21}
# 2
# {'owner': 646, 'date': '2017-11-21', 'desc': 'acousticsact', 'name': 'acoustics', 'claimant': 646}
# 3
# {'owner': 426, 'date': '2017-06-12', 'desc': 'actaction', 'name': 'act', 'claimant': 426}
# 4
# {'owner': 898, 'date': '2017-07-02', 'desc': 'actionactivity', 'name': 'action', 'claimant': 898}
# 5
# {'owner': 136, 'date': '2017-10-26', 'desc': 'activityactor', 'name': 'activity', 'claimant': 136}
# 6
# {'owner': 850, 'date': '2017-06-27', 'desc': 'actoraddition', 'name': 'actor', 'claimant': 850}
# 7
# {'owner': 469, 'date': '2017-09-13', 'desc': 'additionadjustment', 'name': 'addition', 'claimant': 469}
# 8
# {'owner': 91, 'date': '2017-11-04', 'desc': 'adjustmentadvertisement', 'name': 'adjustment', 'claimant': 91}
# 9
# ...
