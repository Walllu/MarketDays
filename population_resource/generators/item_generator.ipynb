# %%
# poster ID
# owner ID
# item ID
# item name
# description
# date posted

# 802 items

import random

f = open("../data/nouns.txt")
arr = []
for line in f:
    line = line[:-1]
    arr.append(line)
f.close()

items = {}

for i in xrange(208):
    
    date = "2017"
    day = str(random.randint(1,30))
    
    if len(day) == 1:
        day = "0" + day
        
    month = str(random.randint(6,12))
    
    if len(month) == 1:
        month = "0" + month
        
    date = date + "-" + month + "-" + day
    
    owner = random.randint(1,100)
    
    items[i + 1] = {}
    items[i + 1]['name'] = arr[i]
    items[i + 1]['owner'] = owner
    items[i + 1]['claimant'] = owner
    items[i + 1]['desc'] = arr[i] + arr[i + 1]
    items[i + 1]['date'] = date
    
    print str(i)
    print items[i + 1]

output = []
for item in items:
    line = ""
    line += items[item]['name'] + "\t"
    line += str(items[item]['owner']) + "\t"
    line += str(items[item]['claimant']) + "\t"
    line += items[item]['desc'] + "\t"
    line += items[item]['date']
    
    print line
    
    output.append(line)

f = open("../data/items.txt", "w")
for item in output:
    f.write(item + "\n")
f.close()
# Out:
# 0
# {'owner': 57, 'date': '2017-12-03', 'desc': 'accountachiever', 'name': 'account', 'claimant': 57}
# 1
# {'owner': 24, 'date': '2017-09-09', 'desc': 'achieveracoustics', 'name': 'achiever', 'claimant': 24}
# 2
# {'owner': 91, 'date': '2017-10-06', 'desc': 'acousticsact', 'name': 'acoustics', 'claimant': 91}
# 3
# {'owner': 13, 'date': '2017-09-19', 'desc': 'actaction', 'name': 'act', 'claimant': 13}
# 4
# {'owner': 34, 'date': '2017-11-28', 'desc': 'actionactivity', 'name': 'action', 'claimant': 34}
# 5
# {'owner': 43, 'date': '2017-09-13', 'desc': 'activityactor', 'name': 'activity', 'claimant': 43}
# 6
# {'owner': 83, 'date': '2017-09-23', 'desc': 'actoraddition', 'name': 'actor', 'claimant': 83}
# 7
# {'owner': 6, 'date': '2017-06-24', 'desc': 'additionadjustment', 'name': 'addition', 'claimant': 6}
# 8
# {'owner': 93, 'date': '2017-08-05', 'desc': 'adjustmentadvertisement', 'name': 'adjustment', 'claimant': 93}
# 9
# {'owner': 53, 'date': '2017-07-29', 'desc': 'advertisementadvice', 'name': 'advertisement', 'claimant': 53}
# 10
# {'owner': 35, 'date': '2017-10-18', 'desc': 'adviceaftermath', 'name': 'advice', 'claimant': 35}
# 11
# {'owner': 93, 'date': '2017-08-08', 'desc': 'aftermathafternoon', 'name': 'aftermath', 'claimant': 93}
# 12
# {'owner': 87, 'date': '2017-06-13', 'desc': 'afternoonafterthought', 'name': 'afternoon', 'claimant': 87}
# 13
# {'owner': 30, 'date': '2017-07-03', 'desc': 'afterthoughtagreement', 'name': 'afterthought', 'claimant': 30}
# 14
# {'owner': 70, 'date': '2017-11-23', 'desc': 'agreementair', 'name': 'agreement', 'claimant': 70}
# 15
# {'owner': 51, 'date': '2017-06-10', 'desc': 'airairplane', 'name': 'air', 'claimant': 51}
# 16
# {'owner': 95, 'date': '2017-11-22', 'desc': 'airplaneairport', 'name': 'airplane', 'claimant': 95}
# 17
# {'owner': 63, 'date': '2017-09-12', 'desc': 'airportalarm', 'name': 'airport', 'claimant': 63}
# 18
# {'owner': 42, 'date': '2017-07-28', 'desc': 'alarmamount', 'name': 'alarm', 'claimant': 42}
# 19
# {'owner': 73, 'date': '2017-10-22', 'desc': 'amountamusement', 'name': 'amount', 'claimant': 73}
# 20
# {'owner': 5, 'date': '2017-08-13', 'desc': 'amusementanger', 'name': 'amusement', 'claimant': 5}
# 21
# {'owner': 53, 'date': '2017-10-19', 'desc': 'angerangle', 'name': 'anger', 'claimant': 53}
# 22
# {'owner': 94, 'date': '2017-08-08', 'desc': 'angleanimal', 'name': 'angle', 'claimant': 94}
# 23
# {'owner': 47, 'date': '2017-09-13', 'desc': 'animalanswer', 'name': 'animal', 'claimant': 47}
# 24
# {'owner': 95, 'date': '2017-10-05', 'desc': 'answerant', 'name': 'answer', 'claimant': 95}
# 25
# {'owner': 57, 'date': '2017-07-03', 'desc': 'antants', 'name': 'ant', 'claimant': 57}
# 26
# {'owner': 94, 'date': '2017-10-02', 'desc': 'antsapparatus', 'name': 'ants', 'claimant': 94}
# 27
# {'owner': 12, 'date': '2017-08-09', 'desc': 'apparatusapparel', 'name': 'apparatus', 'claimant': 12}
# 28
# {'owner': 6, 'date': '2017-11-23', 'desc': 'apparelapple', 'name': 'apparel', 'claimant': 6}
# 29
# {'owner': 2, 'date': '2017-10-17', 'desc': 'appleapples', 'name': 'apple', 'claimant': 2}
# 30
# {'owner': 95, 'date': '2017-08-26', 'desc': 'applesappliance', 'name': 'apples', 'claimant': 95}
# 31
# {'owner': 33, 'date': '2017-11-12', 'desc': 'applianceapproval', 'name': 'appliance', 'claimant': 33}
# 32
# {'owner': 55, 'date': '2017-10-11', 'desc': 'approvalarch', 'name': 'approval', 'claimant': 55}
# 33
# {'owner': 43, 'date': '2017-06-28', 'desc': 'archargument', 'name': 'arch', 'claimant': 43}
# 34
# {'owner': 94, 'date': '2017-07-02', 'desc': 'argumentarithmetic', 'name': 'argument', 'claimant': 94}
# 35
# {'owner': 86, 'date': '2017-11-23', 'desc': 'arithmeticarm', 'name': 'arithmetic', 'claimant': 86}
# 36
# {'owner': 42, 'date': '2017-07-27', 'desc': 'armarmy', 'name': 'arm', 'claimant': 42}
# 37
# {'owner': 33, 'date': '2017-07-15', 'desc': 'armyart', 'name': 'army', 'claimant': 33}
# 38
# {'owner': 5, 'date': '2017-10-11', 'desc': 'artattack', 'name': 'art', 'claimant': 5}
# 39
# {'owner': 40, 'date': '2017-10-12', 'desc': 'attackattempt', 'name': 'attack', 'claimant': 40}
# 40
# {'owner': 56, 'date': '2017-08-22', 'desc': 'attemptattention', 'name': 'attempt', 'claimant': 56}
# 41
# {'owner': 52, 'date': '2017-12-17', 'desc': 'attentionattraction', 'name': 'attention', 'claimant': 52}
# 42
# {'owner': 39, 'date': '2017-07-16', 'desc': 'attractionaunt', 'name': 'attraction', 'claimant': 39}
# 43
# {'owner': 19, 'date': '2017-09-19', 'desc': 'auntauthority', 'name': 'aunt', 'claimant': 19}
# 44
# {'owner': 85, 'date': '2017-06-16', 'desc': 'authoritybabies', 'name': 'authority', 'claimant': 85}
# 45
# {'owner': 20, 'date': '2017-09-04', 'desc': 'babiesbaby', 'name': 'babies', 'claimant': 20}
# 46
# {'owner': 6, 'date': '2017-06-01', 'desc': 'babyback', 'name': 'baby', 'claimant': 6}
# 47
# {'owner': 23, 'date': '2017-08-29', 'desc': 'backbadge', 'name': 'back', 'claimant': 23}
# 48
# {'owner': 4, 'date': '2017-07-14', 'desc': 'badgebag', 'name': 'badge', 'claimant': 4}
# 49
# {'owner': 79, 'date': '2017-08-30', 'desc': 'bagbait', 'name': 'bag', 'claimant': 79}
# 50
# {'owner': 100, 'date': '2017-12-26', 'desc': 'baitbalance', 'name': 'bait', 'claimant': 100}
# 51
# {'owner': 25, 'date': '2017-07-21', 'desc': 'balanceball', 'name': 'balance', 'claimant': 25}
# 52
# {'owner': 78, 'date': '2017-11-30', 'desc': 'ballballoon', 'name': 'ball', 'claimant': 78}
# 53
# {'owner': 67, 'date': '2017-11-22', 'desc': 'balloonballs', 'name': 'balloon', 'claimant': 67}
# 54
# {'owner': 28, 'date': '2017-12-28', 'desc': 'ballsbanana', 'name': 'balls', 'claimant': 28}
# 55
# {'owner': 99, 'date': '2017-08-29', 'desc': 'bananaband', 'name': 'banana', 'claimant': 99}
# 56
# {'owner': 84, 'date': '2017-08-09', 'desc': 'bandbase', 'name': 'band', 'claimant': 84}
# 57
# {'owner': 61, 'date': '2017-12-14', 'desc': 'basebaseball', 'name': 'base', 'claimant': 61}
# 58
# {'owner': 83, 'date': '2017-06-23', 'desc': 'baseballbasin', 'name': 'baseball', 'claimant': 83}
# 59
# {'owner': 45, 'date': '2017-10-25', 'desc': 'basinbasket', 'name': 'basin', 'claimant': 45}
# 60
# {'owner': 57, 'date': '2017-09-18', 'desc': 'basketbasketball', 'name': 'basket', 'claimant': 57}
# 61
# {'owner': 84, 'date': '2017-07-01', 'desc': 'basketballbat', 'name': 'basketball', 'claimant': 84}
# 62
# {'owner': 35, 'date': '2017-11-09', 'desc': 'batbath', 'name': 'bat', 'claimant': 35}
# 63
# {'owner': 82, 'date': '2017-09-23', 'desc': 'bathbattle', 'name': 'bath', 'claimant': 82}
# 64
# {'owner': 28, 'date': '2017-07-22', 'desc': 'battlebead', 'name': 'battle', 'claimant': 28}
# 65
# {'owner': 86, 'date': '2017-11-29', 'desc': 'beadbeam', 'name': 'bead', 'claimant': 86}
# 66
# {'owner': 2, 'date': '2017-09-10', 'desc': 'beambean', 'name': 'beam', 'claimant': 2}
# 67
# {'owner': 68, 'date': '2017-09-11', 'desc': 'beanbear', 'name': 'bean', 'claimant': 68}
# 68
# {'owner': 77, 'date': '2017-10-11', 'desc': 'bearbears', 'name': 'bear', 'claimant': 77}
# 69
# {'owner': 15, 'date': '2017-07-30', 'desc': 'bearsbeast', 'name': 'bears', 'claimant': 15}
# 70
# {'owner': 42, 'date': '2017-07-15', 'desc': 'beastbed', 'name': 'beast', 'claimant': 42}
# 71
# {'owner': 53, 'date': '2017-08-03', 'desc': 'bedbedroom', 'name': 'bed', 'claimant': 53}
# 72
# {'owner': 68, 'date': '2017-08-10', 'desc': 'bedroombeds', 'name': 'bedroom', 'claimant': 68}
# 73
# {'owner': 55, 'date': '2017-12-06', 'desc': 'bedsbee', 'name': 'beds', 'claimant': 55}
# 74
# {'owner': 66, 'date': '2017-09-25', 'desc': 'beebeef', 'name': 'bee', 'claimant': 66}
# 75
# {'owner': 5, 'date': '2017-12-01', 'desc': 'beefbeetle', 'name': 'beef', 'claimant': 5}
# 76
# {'owner': 39, 'date': '2017-07-04', 'desc': 'beetlebeggar', 'name': 'beetle', 'claimant': 39}
# 77
# {'owner': 92, 'date': '2017-11-27', 'desc': 'beggarbeginner', 'name': 'beggar', 'claimant': 92}
# 78
# {'owner': 86, 'date': '2017-06-03', 'desc': 'beginnerbehavior', 'name': 'beginner', 'claimant': 86}
# 79
# {'owner': 95, 'date': '2017-11-22', 'desc': 'behaviorbelief', 'name': 'behavior', 'claimant': 95}
# 80
# {'owner': 28, 'date': '2017-12-06', 'desc': 'beliefbelieve', 'name': 'belief', 'claimant': 28}
# 81
# {'owner': 34, 'date': '2017-08-25', 'desc': 'believebell', 'name': 'believe', 'claimant': 34}
# 82
# {'owner': 82, 'date': '2017-12-13', 'desc': 'bellbells', 'name': 'bell', 'claimant': 82}
# 83
# {'owner': 82, 'date': '2017-06-13', 'desc': 'bellsberry', 'name': 'bells', 'claimant': 82}
# 84
# {'owner': 74, 'date': '2017-10-30', 'desc': 'berrybike', 'name': 'berry', 'claimant': 74}
# 85
# {'owner': 65, 'date': '2017-06-20', 'desc': 'bikebikes', 'name': 'bike', 'claimant': 65}
# 86
# {'owner': 100, 'date': '2017-08-30', 'desc': 'bikesbird', 'name': 'bikes', 'claimant': 100}
# 87
# {'owner': 99, 'date': '2017-11-04', 'desc': 'birdbirds', 'name': 'bird', 'claimant': 99}
# 88
# {'owner': 27, 'date': '2017-07-15', 'desc': 'birdsbirth', 'name': 'birds', 'claimant': 27}
# 89
# {'owner': 65, 'date': '2017-06-10', 'desc': 'birthbirthday', 'name': 'birth', 'claimant': 65}
# 90
# {'owner': 95, 'date': '2017-12-12', 'desc': 'birthdaybit', 'name': 'birthday', 'claimant': 95}
# 91
# {'owner': 58, 'date': '2017-11-13', 'desc': 'bitbite', 'name': 'bit', 'claimant': 58}
# 92
# {'owner': 74, 'date': '2017-06-29', 'desc': 'biteblade', 'name': 'bite', 'claimant': 74}
# 93
# {'owner': 66, 'date': '2017-11-03', 'desc': 'bladeblood', 'name': 'blade', 'claimant': 66}
# 94
# {'owner': 10, 'date': '2017-12-28', 'desc': 'bloodblow', 'name': 'blood', 'claimant': 10}
# 95
# {'owner': 42, 'date': '2017-11-20', 'desc': 'blowboard', 'name': 'blow', 'claimant': 42}
# 96
# {'owner': 45, 'date': '2017-08-28', 'desc': 'boardboat', 'name': 'board', 'claimant': 45}
# 97
# {'owner': 73, 'date': '2017-06-26', 'desc': 'boatboats', 'name': 'boat', 'claimant': 73}
# 98
# {'owner': 45, 'date': '2017-06-27', 'desc': 'boatsbody', 'name': 'boats', 'claimant': 45}
# 99
# {'owner': 83, 'date': '2017-11-26', 'desc': 'bodybomb', 'name': 'body', 'claimant': 83}
# 100
# {'owner': 32, 'date': '2017-11-04', 'desc': 'bombbone', 'name': 'bomb', 'claimant': 32}
# 101
# {'owner': 74, 'date': '2017-07-11', 'desc': 'bonebook', 'name': 'bone', 'claimant': 74}
# 102
# {'owner': 41, 'date': '2017-10-08', 'desc': 'bookbooks', 'name': 'book', 'claimant': 41}
# 103
# {'owner': 76, 'date': '2017-11-29', 'desc': 'booksboot', 'name': 'books', 'claimant': 76}
# 104
# {'owner': 87, 'date': '2017-07-01', 'desc': 'bootborder', 'name': 'boot', 'claimant': 87}
# 105
# {'owner': 56, 'date': '2017-06-08', 'desc': 'borderbottle', 'name': 'border', 'claimant': 56}
# 106
# {'owner': 50, 'date': '2017-09-29', 'desc': 'bottleboundary', 'name': 'bottle', 'claimant': 50}
# 107
# {'owner': 85, 'date': '2017-08-24', 'desc': 'boundarybox', 'name': 'boundary', 'claimant': 85}
# 108
# {'owner': 90, 'date': '2017-06-16', 'desc': 'boxboy', 'name': 'box', 'claimant': 90}
# 109
# {'owner': 61, 'date': '2017-11-03', 'desc': 'boyboys', 'name': 'boy', 'claimant': 61}
# 110
# {'owner': 19, 'date': '2017-06-16', 'desc': 'boysbrain', 'name': 'boys', 'claimant': 19}
# 111
# {'owner': 8, 'date': '2017-07-08', 'desc': 'brainbrake', 'name': 'brain', 'claimant': 8}
# 112
# {'owner': 38, 'date': '2017-11-14', 'desc': 'brakebranch', 'name': 'brake', 'claimant': 38}
# 113
# {'owner': 50, 'date': '2017-12-17', 'desc': 'branchbrass', 'name': 'branch', 'claimant': 50}
# 114
# {'owner': 98, 'date': '2017-08-29', 'desc': 'brassbread', 'name': 'brass', 'claimant': 98}
# 115
# {'owner': 89, 'date': '2017-11-18', 'desc': 'breadbreakfast', 'name': 'bread', 'claimant': 89}
# 116
# {'owner': 1, 'date': '2017-07-26', 'desc': 'breakfastbreath', 'name': 'breakfast', 'claimant': 1}
# 117
# {'owner': 23, 'date': '2017-11-04', 'desc': 'breathbrick', 'name': 'breath', 'claimant': 23}
# 118
# {'owner': 40, 'date': '2017-12-30', 'desc': 'brickbridge', 'name': 'brick', 'claimant': 40}
# 119
# {'owner': 35, 'date': '2017-07-25', 'desc': 'bridgebrother', 'name': 'bridge', 'claimant': 35}
# 120
# {'owner': 84, 'date': '2017-10-23', 'desc': 'brotherbrothers', 'name': 'brother', 'claimant': 84}
# 121
# {'owner': 76, 'date': '2017-09-22', 'desc': 'brothersbrush', 'name': 'brothers', 'claimant': 76}
# 122
# {'owner': 95, 'date': '2017-11-04', 'desc': 'brushbubble', 'name': 'brush', 'claimant': 95}
# 123
# {'owner': 6, 'date': '2017-09-12', 'desc': 'bubblebucket', 'name': 'bubble', 'claimant': 6}
# 124
# {'owner': 12, 'date': '2017-09-23', 'desc': 'bucketbuilding', 'name': 'bucket', 'claimant': 12}
# 125
# {'owner': 45, 'date': '2017-12-16', 'desc': 'buildingbulb', 'name': 'building', 'claimant': 45}
# 126
# {'owner': 67, 'date': '2017-12-14', 'desc': 'bulbbun', 'name': 'bulb', 'claimant': 67}
# 127
# {'owner': 10, 'date': '2017-07-25', 'desc': 'bunburn', 'name': 'bun', 'claimant': 10}
# 128
# {'owner': 49, 'date': '2017-08-29', 'desc': 'burnburst', 'name': 'burn', 'claimant': 49}
# 129
# {'owner': 76, 'date': '2017-10-09', 'desc': 'burstbushes', 'name': 'burst', 'claimant': 76}
# 130
# {'owner': 20, 'date': '2017-08-02', 'desc': 'bushesbusiness', 'name': 'bushes', 'claimant': 20}
# 131
# {'owner': 16, 'date': '2017-10-10', 'desc': 'businessbutter', 'name': 'business', 'claimant': 16}
# 132
# {'owner': 50, 'date': '2017-09-28', 'desc': 'butterbutton', 'name': 'butter', 'claimant': 50}
# 133
# {'owner': 65, 'date': '2017-08-27', 'desc': 'buttoncabbage', 'name': 'button', 'claimant': 65}
# 134
# {'owner': 9, 'date': '2017-12-23', 'desc': 'cabbagecable', 'name': 'cabbage', 'claimant': 9}
# 135
# {'owner': 7, 'date': '2017-12-13', 'desc': 'cablecactus', 'name': 'cable', 'claimant': 7}
# 136
# {'owner': 56, 'date': '2017-10-18', 'desc': 'cactuscake', 'name': 'cactus', 'claimant': 56}
# 137
# {'owner': 80, 'date': '2017-06-08', 'desc': 'cakecakes', 'name': 'cake', 'claimant': 80}
# 138
# {'owner': 52, 'date': '2017-09-05', 'desc': 'cakescalculator', 'name': 'cakes', 'claimant': 52}
# 139
# {'owner': 54, 'date': '2017-07-18', 'desc': 'calculatorcalendar', 'name': 'calculator', 'claimant': 54}
# 140
# {'owner': 86, 'date': '2017-09-28', 'desc': 'calendarcamera', 'name': 'calendar', 'claimant': 86}
# 141
# {'owner': 98, 'date': '2017-10-18', 'desc': 'cameracamp', 'name': 'camera', 'claimant': 98}
# 142
# {'owner': 65, 'date': '2017-10-13', 'desc': 'campcan', 'name': 'camp', 'claimant': 65}
# 143
# {'owner': 84, 'date': '2017-12-22', 'desc': 'cancannon', 'name': 'can', 'claimant': 84}
# 144
# {'owner': 53, 'date': '2017-12-20', 'desc': 'cannoncanvas', 'name': 'cannon', 'claimant': 53}
# 145
# {'owner': 41, 'date': '2017-11-20', 'desc': 'canvascap', 'name': 'canvas', 'claimant': 41}
# 146
# {'owner': 10, 'date': '2017-08-02', 'desc': 'capcaption', 'name': 'cap', 'claimant': 10}
# 147
# {'owner': 93, 'date': '2017-09-21', 'desc': 'captioncar', 'name': 'caption', 'claimant': 93}
# 148
# {'owner': 53, 'date': '2017-12-05', 'desc': 'carcard', 'name': 'car', 'claimant': 53}
# 149
# {'owner': 33, 'date': '2017-07-02', 'desc': 'cardcare', 'name': 'card', 'claimant': 33}
# 150
# {'owner': 72, 'date': '2017-10-17', 'desc': 'carecarpenter', 'name': 'care', 'claimant': 72}
# 151
# {'owner': 41, 'date': '2017-06-11', 'desc': 'carpentercarriage', 'name': 'carpenter', 'claimant': 41}
# 152
# {'owner': 58, 'date': '2017-07-25', 'desc': 'carriagecars', 'name': 'carriage', 'claimant': 58}
# 153
# {'owner': 42, 'date': '2017-11-04', 'desc': 'carscart', 'name': 'cars', 'claimant': 42}
# 154
# {'owner': 89, 'date': '2017-09-20', 'desc': 'cartcast', 'name': 'cart', 'claimant': 89}
# 155
# {'owner': 83, 'date': '2017-06-20', 'desc': 'castcat', 'name': 'cast', 'claimant': 83}
# 156
# {'owner': 50, 'date': '2017-11-29', 'desc': 'catcats', 'name': 'cat', 'claimant': 50}
# 157
# {'owner': 47, 'date': '2017-11-17', 'desc': 'catscattle', 'name': 'cats', 'claimant': 47}
# 158
# {'owner': 53, 'date': '2017-07-01', 'desc': 'cattlecause', 'name': 'cattle', 'claimant': 53}
# 159
# {'owner': 64, 'date': '2017-10-27', 'desc': 'causecave', 'name': 'cause', 'claimant': 64}
# 160
# {'owner': 43, 'date': '2017-06-12', 'desc': 'cavecelery', 'name': 'cave', 'claimant': 43}
# 161
# {'owner': 73, 'date': '2017-09-10', 'desc': 'celerycellar', 'name': 'celery', 'claimant': 73}
# 162
# {'owner': 84, 'date': '2017-11-04', 'desc': 'cellarcemetery', 'name': 'cellar', 'claimant': 84}
# 163
# {'owner': 11, 'date': '2017-11-12', 'desc': 'cemeterycent', 'name': 'cemetery', 'claimant': 11}
# 164
# {'owner': 41, 'date': '2017-08-05', 'desc': 'centchain', 'name': 'cent', 'claimant': 41}
# 165
# {'owner': 39, 'date': '2017-08-08', 'desc': 'chainchair', 'name': 'chain', 'claimant': 39}
# 166
# {'owner': 79, 'date': '2017-12-05', 'desc': 'chairchairs', 'name': 'chair', 'claimant': 79}
# 167
# {'owner': 22, 'date': '2017-06-25', 'desc': 'chairschalk', 'name': 'chairs', 'claimant': 22}
# 168
# {'owner': 90, 'date': '2017-08-02', 'desc': 'chalkchance', 'name': 'chalk', 'claimant': 90}
# 169
# {'owner': 85, 'date': '2017-10-29', 'desc': 'chancechange', 'name': 'chance', 'claimant': 85}
# 170
# {'owner': 5, 'date': '2017-12-24', 'desc': 'changechannel', 'name': 'change', 'claimant': 5}
# 171
# {'owner': 98, 'date': '2017-06-29', 'desc': 'channelcheese', 'name': 'channel', 'claimant': 98}
# 172
# {'owner': 91, 'date': '2017-07-16', 'desc': 'cheesecherries', 'name': 'cheese', 'claimant': 91}
# 173
# {'owner': 31, 'date': '2017-10-17', 'desc': 'cherriescherry', 'name': 'cherries', 'claimant': 31}
# 174
# {'owner': 36, 'date': '2017-08-07', 'desc': 'cherrychess', 'name': 'cherry', 'claimant': 36}
# 175
# {'owner': 39, 'date': '2017-12-08', 'desc': 'chesschicken', 'name': 'chess', 'claimant': 39}
# 176
# {'owner': 40, 'date': '2017-06-07', 'desc': 'chickenchickens', 'name': 'chicken', 'claimant': 40}
# 177
# {'owner': 48, 'date': '2017-09-26', 'desc': 'chickenschildren', 'name': 'chickens', 'claimant': 48}
# 178
# {'owner': 43, 'date': '2017-11-09', 'desc': 'childrenchin', 'name': 'children', 'claimant': 43}
# 179
# {'owner': 61, 'date': '2017-12-19', 'desc': 'chinchurch', 'name': 'chin', 'claimant': 61}
# 180
# {'owner': 75, 'date': '2017-08-22', 'desc': 'churchcircle', 'name': 'church', 'claimant': 75}
# 181
# {'owner': 35, 'date': '2017-12-28', 'desc': 'circleclam', 'name': 'circle', 'claimant': 35}
# 182
# {'owner': 42, 'date': '2017-09-24', 'desc': 'clamclass', 'name': 'clam', 'claimant': 42}
# 183
# {'owner': 47, 'date': '2017-09-02', 'desc': 'classclock', 'name': 'class', 'claimant': 47}
# 184
# {'owner': 92, 'date': '2017-11-19', 'desc': 'clockclocks', 'name': 'clock', 'claimant': 92}
# 185
# {'owner': 58, 'date': '2017-11-26', 'desc': 'clockscloth', 'name': 'clocks', 'claimant': 58}
# 186
# {'owner': 89, 'date': '2017-09-29', 'desc': 'clothcloud', 'name': 'cloth', 'claimant': 89}
# 187
# {'owner': 10, 'date': '2017-07-25', 'desc': 'cloudclouds', 'name': 'cloud', 'claimant': 10}
# 188
# {'owner': 71, 'date': '2017-08-04', 'desc': 'cloudsclover', 'name': 'clouds', 'claimant': 71}
# 189
# {'owner': 79, 'date': '2017-06-05', 'desc': 'cloverclub', 'name': 'clover', 'claimant': 79}
# 190
# {'owner': 36, 'date': '2017-10-22', 'desc': 'clubcoach', 'name': 'club', 'claimant': 36}
# 191
# {'owner': 54, 'date': '2017-07-28', 'desc': 'coachcoal', 'name': 'coach', 'claimant': 54}
# 192
# {'owner': 54, 'date': '2017-08-12', 'desc': 'coalcoast', 'name': 'coal', 'claimant': 54}
# 193
# {'owner': 57, 'date': '2017-09-16', 'desc': 'coastcoat', 'name': 'coast', 'claimant': 57}
# 194
# {'owner': 34, 'date': '2017-09-24', 'desc': 'coatcobweb', 'name': 'coat', 'claimant': 34}
# 195
# {'owner': 92, 'date': '2017-08-24', 'desc': 'cobwebcoil', 'name': 'cobweb', 'claimant': 92}
# 196
# {'owner': 17, 'date': '2017-10-01', 'desc': 'coilcollar', 'name': 'coil', 'claimant': 17}
# 197
# {'owner': 70, 'date': '2017-07-09', 'desc': 'collarcolor', 'name': 'collar', 'claimant': 70}
# 198
# {'owner': 38, 'date': '2017-11-02', 'desc': 'colorcomb', 'name': 'color', 'claimant': 38}
# 199
# {'owner': 8, 'date': '2017-12-08', 'desc': 'combcomfort', 'name': 'comb', 'claimant': 8}
# 200
# {'owner': 38, 'date': '2017-06-26', 'desc': 'comfortcommittee', 'name': 'comfort', 'claimant': 38}
# 201
# {'owner': 46, 'date': '2017-08-07', 'desc': 'committeecompany', 'name': 'committee', 'claimant': 46}
# 202
# {'owner': 98, 'date': '2017-10-26', 'desc': 'companycomparison', 'name': 'company', 'claimant': 98}
# 203
# {'owner': 56, 'date': '2017-10-07', 'desc': 'comparisoncompetition', 'name': 'comparison', 'claimant': 56}
# 204
# {'owner': 83, 'date': '2017-08-01', 'desc': 'competitioncondition', 'name': 'competition', 'claimant': 83}
# 205
# {'owner': 15, 'date': '2017-12-13', 'desc': 'conditionconnection', 'name': 'condition', 'claimant': 15}
# 206
# {'owner': 37, 'date': '2017-07-16', 'desc': 'connectioncontrol', 'name': 'connection', 'claimant': 37}
# 207
# {'owner': 85, 'date': '2017-12-05', 'desc': 'controlcook', 'name': 'control', 'claimant': 85}
# account	57	57	accountachiever	2017-12-03
# achiever	24	24	achieveracoustics	2017-09-09
# acoustics	91	91	acousticsact	2017-10-06
# act	13	13	actaction	2017-09-19
# action	34	34	actionactivity	2017-11-28
# activity	43	43	activityactor	2017-09-13
# actor	83	83	actoraddition	2017-09-23
# addition	6	6	additionadjustment	2017-06-24
# adjustment	93	93	adjustmentadvertisement	2017-08-05
# advertisement	53	53	advertisementadvice	2017-07-29
# advice	35	35	adviceaftermath	2017-10-18
# aftermath	93	93	aftermathafternoon	2017-08-08
# afternoon	87	87	afternoonafterthought	2017-06-13
# afterthought	30	30	afterthoughtagreement	2017-07-03
# agreement	70	70	agreementair	2017-11-23
# air	51	51	airairplane	2017-06-10
# airplane	95	95	airplaneairport	2017-11-22
# airport	63	63	airportalarm	2017-09-12
# alarm	42	42	alarmamount	2017-07-28
# amount	73	73	amountamusement	2017-10-22
# amusement	5	5	amusementanger	2017-08-13
# anger	53	53	angerangle	2017-10-19
# angle	94	94	angleanimal	2017-08-08
# animal	47	47	animalanswer	2017-09-13
# answer	95	95	answerant	2017-10-05
# ant	57	57	antants	2017-07-03
# ants	94	94	antsapparatus	2017-10-02
# apparatus	12	12	apparatusapparel	2017-08-09
# apparel	6	6	apparelapple	2017-11-23
# apple	2	2	appleapples	2017-10-17
# apples	95	95	applesappliance	2017-08-26
# appliance	33	33	applianceapproval	2017-11-12
# approval	55	55	approvalarch	2017-10-11
# arch	43	43	archargument	2017-06-28
# argument	94	94	argumentarithmetic	2017-07-02
# arithmetic	86	86	arithmeticarm	2017-11-23
# arm	42	42	armarmy	2017-07-27
# army	33	33	armyart	2017-07-15
# art	5	5	artattack	2017-10-11
# attack	40	40	attackattempt	2017-10-12
# attempt	56	56	attemptattention	2017-08-22
# attention	52	52	attentionattraction	2017-12-17
# attraction	39	39	attractionaunt	2017-07-16
# aunt	19	19	auntauthority	2017-09-19
# authority	85	85	authoritybabies	2017-06-16
# babies	20	20	babiesbaby	2017-09-04
# baby	6	6	babyback	2017-06-01
# back	23	23	backbadge	2017-08-29
# badge	4	4	badgebag	2017-07-14
# bag	79	79	bagbait	2017-08-30
# bait	100	100	baitbalance	2017-12-26
# balance	25	25	balanceball	2017-07-21
# ball	78	78	ballballoon	2017-11-30
# balloon	67	67	balloonballs	2017-11-22
# balls	28	28	ballsbanana	2017-12-28
# banana	99	99	bananaband	2017-08-29
# band	84	84	bandbase	2017-08-09
# base	61	61	basebaseball	2017-12-14
# baseball	83	83	baseballbasin	2017-06-23
# basin	45	45	basinbasket	2017-10-25
# basket	57	57	basketbasketball	2017-09-18
# basketball	84	84	basketballbat	2017-07-01
# bat	35	35	batbath	2017-11-09
# bath	82	82	bathbattle	2017-09-23
# battle	28	28	battlebead	2017-07-22
# bead	86	86	beadbeam	2017-11-29
# beam	2	2	beambean	2017-09-10
# bean	68	68	beanbear	2017-09-11
# bear	77	77	bearbears	2017-10-11
# bears	15	15	bearsbeast	2017-07-30
# beast	42	42	beastbed	2017-07-15
# bed	53	53	bedbedroom	2017-08-03
# bedroom	68	68	bedroombeds	2017-08-10
# beds	55	55	bedsbee	2017-12-06
# bee	66	66	beebeef	2017-09-25
# beef	5	5	beefbeetle	2017-12-01
# beetle	39	39	beetlebeggar	2017-07-04
# beggar	92	92	beggarbeginner	2017-11-27
# beginner	86	86	beginnerbehavior	2017-06-03
# behavior	95	95	behaviorbelief	2017-11-22
# belief	28	28	beliefbelieve	2017-12-06
# believe	34	34	believebell	2017-08-25
# bell	82	82	bellbells	2017-12-13
# bells	82	82	bellsberry	2017-06-13
# berry	74	74	berrybike	2017-10-30
# bike	65	65	bikebikes	2017-06-20
# bikes	100	100	bikesbird	2017-08-30
# bird	99	99	birdbirds	2017-11-04
# birds	27	27	birdsbirth	2017-07-15
# birth	65	65	birthbirthday	2017-06-10
# birthday	95	95	birthdaybit	2017-12-12
# bit	58	58	bitbite	2017-11-13
# bite	74	74	biteblade	2017-06-29
# blade	66	66	bladeblood	2017-11-03
# blood	10	10	bloodblow	2017-12-28
# blow	42	42	blowboard	2017-11-20
# board	45	45	boardboat	2017-08-28
# boat	73	73	boatboats	2017-06-26
# boats	45	45	boatsbody	2017-06-27
# body	83	83	bodybomb	2017-11-26
# bomb	32	32	bombbone	2017-11-04
# bone	74	74	bonebook	2017-07-11
# book	41	41	bookbooks	2017-10-08
# books	76	76	booksboot	2017-11-29
# boot	87	87	bootborder	2017-07-01
# border	56	56	borderbottle	2017-06-08
# bottle	50	50	bottleboundary	2017-09-29
# boundary	85	85	boundarybox	2017-08-24
# box	90	90	boxboy	2017-06-16
# boy	61	61	boyboys	2017-11-03
# boys	19	19	boysbrain	2017-06-16
# brain	8	8	brainbrake	2017-07-08
# brake	38	38	brakebranch	2017-11-14
# branch	50	50	branchbrass	2017-12-17
# brass	98	98	brassbread	2017-08-29
# bread	89	89	breadbreakfast	2017-11-18
# breakfast	1	1	breakfastbreath	2017-07-26
# breath	23	23	breathbrick	2017-11-04
# brick	40	40	brickbridge	2017-12-30
# bridge	35	35	bridgebrother	2017-07-25
# brother	84	84	brotherbrothers	2017-10-23
# brothers	76	76	brothersbrush	2017-09-22
# brush	95	95	brushbubble	2017-11-04
# bubble	6	6	bubblebucket	2017-09-12
# bucket	12	12	bucketbuilding	2017-09-23
# building	45	45	buildingbulb	2017-12-16
# bulb	67	67	bulbbun	2017-12-14
# bun	10	10	bunburn	2017-07-25
# burn	49	49	burnburst	2017-08-29
# burst	76	76	burstbushes	2017-10-09
# bushes	20	20	bushesbusiness	2017-08-02
# business	16	16	businessbutter	2017-10-10
# butter	50	50	butterbutton	2017-09-28
# button	65	65	buttoncabbage	2017-08-27
# cabbage	9	9	cabbagecable	2017-12-23
# cable	7	7	cablecactus	2017-12-13
# cactus	56	56	cactuscake	2017-10-18
# cake	80	80	cakecakes	2017-06-08
# cakes	52	52	cakescalculator	2017-09-05
# calculator	54	54	calculatorcalendar	2017-07-18
# calendar	86	86	calendarcamera	2017-09-28
# camera	98	98	cameracamp	2017-10-18
# camp	65	65	campcan	2017-10-13
# can	84	84	cancannon	2017-12-22
# cannon	53	53	cannoncanvas	2017-12-20
# canvas	41	41	canvascap	2017-11-20
# cap	10	10	capcaption	2017-08-02
# caption	93	93	captioncar	2017-09-21
# car	53	53	carcard	2017-12-05
# card	33	33	cardcare	2017-07-02
# care	72	72	carecarpenter	2017-10-17
# carpenter	41	41	carpentercarriage	2017-06-11
# carriage	58	58	carriagecars	2017-07-25
# cars	42	42	carscart	2017-11-04
# cart	89	89	cartcast	2017-09-20
# cast	83	83	castcat	2017-06-20
# cat	50	50	catcats	2017-11-29
# cats	47	47	catscattle	2017-11-17
# cattle	53	53	cattlecause	2017-07-01
# cause	64	64	causecave	2017-10-27
# cave	43	43	cavecelery	2017-06-12
# celery	73	73	celerycellar	2017-09-10
# cellar	84	84	cellarcemetery	2017-11-04
# cemetery	11	11	cemeterycent	2017-11-12
# cent	41	41	centchain	2017-08-05
# chain	39	39	chainchair	2017-08-08
# chair	79	79	chairchairs	2017-12-05
# chairs	22	22	chairschalk	2017-06-25
# chalk	90	90	chalkchance	2017-08-02
# chance	85	85	chancechange	2017-10-29
# change	5	5	changechannel	2017-12-24
# channel	98	98	channelcheese	2017-06-29
# cheese	91	91	cheesecherries	2017-07-16
# cherries	31	31	cherriescherry	2017-10-17
# cherry	36	36	cherrychess	2017-08-07
# chess	39	39	chesschicken	2017-12-08
# chicken	40	40	chickenchickens	2017-06-07
# chickens	48	48	chickenschildren	2017-09-26
# children	43	43	childrenchin	2017-11-09
# chin	61	61	chinchurch	2017-12-19
# church	75	75	churchcircle	2017-08-22
# circle	35	35	circleclam	2017-12-28
# clam	42	42	clamclass	2017-09-24
# class	47	47	classclock	2017-09-02
# clock	92	92	clockclocks	2017-11-19
# clocks	58	58	clockscloth	2017-11-26
# cloth	89	89	clothcloud	2017-09-29
# cloud	10	10	cloudclouds	2017-07-25
# clouds	71	71	cloudsclover	2017-08-04
# clover	79	79	cloverclub	2017-06-05
# club	36	36	clubcoach	2017-10-22
# coach	54	54	coachcoal	2017-07-28
# coal	54	54	coalcoast	2017-08-12
# coast	57	57	coastcoat	2017-09-16
# coat	34	34	coatcobweb	2017-09-24
# cobweb	92	92	cobwebcoil	2017-08-24
# coil	17	17	coilcollar	2017-10-01
# collar	70	70	collarcolor	2017-07-09
# color	38	38	colorcomb	2017-11-02
# comb	8	8	combcomfort	2017-12-08
# comfort	38	38	comfortcommittee	2017-06-26
# committee	46	46	committeecompany	2017-08-07
# company	98	98	companycomparison	2017-10-26
# comparison	56	56	comparisoncompetition	2017-10-07
# competition	83	83	competitioncondition	2017-08-01
# condition	15	15	conditionconnection	2017-12-13
# connection	37	37	connectioncontrol	2017-07-16
# control	85	85	controlcook	2017-12-05
